# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui
df_mat['percentual'] = (df_mat['Qt_acertos']/24)*100

df_por['percentual'] = (df_por['Qt_acertos']/18)*100

df_geo['percentual'] = (df_geo['Qt_acertos']/8)*100

df_ing['percentual'] = (df_ing['Qt_acertos']/8)*100

df_his['percentual'] = (df_his['Qt_acertos']/8)*100

df_fis['percentual'] = (df_fis['Qt_acertos']/12)*100

df_qui['percentual'] = (df_qui['Qt_acertos']/12)*100
df_qui
# Out:
#     Qt_acertos  percentual
# 0            3   25.000000
# 1            8   66.666667
# 2            4   33.333333
# 3            8   66.666667
# 4            3   25.000000
# ..         ...         ...
# 95           3   25.000000
# 96           3   25.000000
# 97           5   41.666667
# 98          11   91.666667
# 99           2   16.666667
#
# [100 rows x 2 columns]

# %%
# 2) Seu código aqui
df_total = pd.concat([df_mat['Qt_acertos'],
                     df_por['Qt_acertos'],
                     df_geo['Qt_acertos'],
                     df_ing['Qt_acertos'],
                     df_his['Qt_acertos'],
                     df_fis['Qt_acertos'],
                     df_qui['Qt_acertos']], axis = 1)
df_total.columns = ['matematica','portugues','geografia','ingles','historia','fisica','quimica']
df_total.index= range(1,101)
df_total['total_de_acertos'] = df_total.sum(axis = 1)
df_total
# Out:
#      matematica  portugues  geografia  ingles  historia  fisica  quimica  \
# 1             6          7          7       3         1       8        3
# 2            19         10          0       0         0      11        8
# 3            14         16          0       5         7       4        4
# 4            10          7          3       4         0       0        8
# 5             7          2          2       7         0       9        3
# ..          ...        ...        ...     ...       ...     ...      ...
# 96            6          4          7       1         4       9        3
# 97            8          1          4       6         1       4        3
# 98           23          5          0       2         4       1        5
# 99            0         10          3       1         5      10       11
# 100          11         15          0       1         6       7        2
#
#      total_de_acertos
# 1                  35
# 2                  48
# ...

# %%
# 3) Seu código aqui
df_total['percentual_total'] = (df_total['total_de_acertos']/90)*100
df_total
# Out:
#      matematica  portugues  geografia  ingles  historia  fisica  quimica  \
# 1             6          7          7       3         1       8        3
# 2            19         10          0       0         0      11        8
# 3            14         16          0       5         7       4        4
# 4            10          7          3       4         0       0        8
# 5             7          2          2       7         0       9        3
# ..          ...        ...        ...     ...       ...     ...      ...
# 96            6          4          7       1         4       9        3
# 97            8          1          4       6         1       4        3
# 98           23          5          0       2         4       1        5
# 99            0         10          3       1         5      10       11
# 100          11         15          0       1         6       7        2
#
#      total_de_acertos  percentual_total
# 1                  35         38.888889
# ...

# %%
# 4) Seu código aqui
df_total['passou'] = 0
df_total.loc[df_total['percentual_total'] > 45, 'passou'] = 1
total = df_total['passou'].sum()
print(f'O total de alunos que passaram foi {total}')
# Out:
# O total de alunos que passaram foi 47

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# seu código aqui
df_desqualificados = df_total[(df_total['passou'] == 1) &((df_total['matematica'] == 0) |(df_total['quimica'] == 0) |(df_total['fisica'] == 0))]

total_alunos = df_desqualificados.shape[0]

print(total_alunos)

df_desqualificados[['historia','geografia']].mean().sum()

df_qualificados = df_total[(df_total['passou'] == 1)].drop(df_desqualificados.index)
# Out:
# 6

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAM/part-00000-e45b1ab6-500c-4f78-a408-7e62ff651112.c000.csv'
# na atividade fala acre mas a base de dados é da amazonia, e não estava funcionando, por isso pequei um novo link para utilizar na miha ativide
df = pd.read_csv(arquivo,sep=';',nrows=10000)

# %%
# 1) Sua solução aqui
df1 = df
total_vacinas = df1.shape[0]
total_vacinas
# Out:
# 10000

# %%
# 2)

num_pacientes_vac = df1['paciente_id'].nunique()
num_pacientes_vac
# Out:
# 9988

# %%
# 3)
primeira_dose = df1[(df1['vacina_descricao_dose'] == '1ª Dose')]['paciente_id'].nunique()
# num_pac_1d = primeira_dose['paciente_id'].nunique()
# num_pac_1d
primeira_dose
# Out:
# 3299

# %%
# 3) solução alternativa
df1.head(1)
# Out:
#                                  document_id  \
# 0  d47515f1-dd32-471f-88f0-7ef68ab5837f-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  12546b4edc103a7807cc92fffc9569bcffbf89fe305b3e...              36
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1985-07-22                          M                       99
#
#   paciente_racaCor_valor  paciente_endereco_coIbgeMunicipio  \
# 0         SEM INFORMACAO                           130260.0
#
#    paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                      10.0                        MANAUS  ...
#
#   vacina_categoria_codigo vacina_categoria_nome  vacina_lote  \
# 0                     2.0          Faixa Etária       FM3457
#
#   vacina_fabricante_nome  vacina_fabricante_referencia vacina_dataAplicacao  \
# 0                 PFIZER                           NaN           2022-01-17
#
# ...

# %%
# 4)
df1[(df1['paciente_idade'] < 18)]['paciente_id'].nunique()
# Out:
# 2285

# %%
# 5)

df1.loc[:, 'estabelecimento_valor':'sistema_origem']
df1[df1['paciente_idade']<18]['estabelecimento_municipio_codigo'].nunique()
# Out:
# 61

# %%
df1.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
df1.loc[:, 'document_id':'sistema_origem'].head(1)
# Out:
#                                  document_id  \
# 0  d47515f1-dd32-471f-88f0-7ef68ab5837f-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  12546b4edc103a7807cc92fffc9569bcffbf89fe305b3e...              36
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1985-07-22                          M                       99
#
#   paciente_racaCor_valor  paciente_endereco_coIbgeMunicipio  \
# 0         SEM INFORMACAO                           130260.0
#
#    paciente_endereco_coPais paciente_endereco_nmMunicipio  ...  \
# 0                      10.0                        MANAUS  ...
#
#   vacina_categoria_codigo vacina_categoria_nome  vacina_lote  \
# 0                     2.0          Faixa Etária       FM3457
#
#   vacina_fabricante_nome  vacina_fabricante_referencia vacina_dataAplicacao  \
# 0                 PFIZER                           NaN           2022-01-17
#
# ...

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
df_under_18 = df1[df1['paciente_idade'] < 18]
df2 = df1[df1['estabelecimento_municipio_codigo'].isin(df_under_18['estabelecimento_municipio_codigo'].unique())].reset_index()
df2 = df2.loc[:, 'estabelecimento_valor':'estabelecimento_uf']
vacinas_por_estabelecimento = df_under_18.groupby('estabelecimento_municipio_codigo').size().reset_index(name='quantidade_vacinas')
vacinas_por_estabelecimento
# Out:
#     estabelecimento_municipio_codigo  quantidade_vacinas
# 0                             130002                  17
# 1                             130006                   5
# 2                             130008                   3
# 3                             130010                   5
# 4                             130014                   2
# ..                               ...                 ...
# 56                            130420                  63
# 57                            130423                  17
# 58                            130426                  10
# 59                            130430                  17
# 60                            130440                  19
#
# [61 rows x 2 columns]

# %%
#1)

df_under_18 = df1[df1['paciente_idade'] < 18].copy()

# %%
# 2)
df_under_18.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
# 3)
df_under_18['vacina_categoria_nome'].value_counts()
# Out:
# vacina_categoria_nome
# Faixa Etária                                      1445
# Povos Indígenas                                    152
# Povos e Comunidades Tradicionais                    61
# Comorbidades                                        12
# Gestantes                                            8
# Trabalhadores de Saúde                               3
# Pessoas com Deficiência                              1
# Outros                                               1
# Pessoas de 60 anos ou mais institucionalizadas       1
# Name: count, dtype: int64

# %%
# 4)
lista_estabelecimento = ['estabelecimento_valor',
       'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']

# %%
# 5)
df_under_18 = df_under_18.loc[:, lista_estabelecimento]
# Out:
#       estabelecimento_valor  \
# 2                   2016397
# 6                   2016818
# 11                  2014750
# 15                  6771513
# 21                  7401426
# ...                     ...
# 9990                3581659
# 9991                2016060
# 9992                2019485
# 9995                5477018
# 9996                2017482
#
#                             estabelecimento_razaoSocial  \
# 2                   SECRETARIA DE ESTADO DA SAUDE SUSAM
# 6                     PREFEITURA MUNICIPAL DE PARINTINS
# 11                 MANAUS SECRETARIA MUNICIPAL DE SAUDE
# 15    DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
# 21                              MUNICIPIO DE MANACAPURU
# ...                                                 ...
# 9990                       PREFEITURA MUNICIPAL DE TEFE
# 9991               MANAUS SECRETARIA MUNICIPAL DE SAUDE
# 9992                      PREFEITURA MUNICIPAL DE MAUES
# ...

# %%
# 6)
df_under_18 = df_under_18.drop_duplicates()

# %%
estabelecimento_vacinas_count = df_under_18.groupby('estabelecimento_valor').size().reset_index(name='quantidade_vacinas')
final_df = df_under_18.merge(estabelecimento_vacinas_count, on='estabelecimento_valor')

# %%
final_df
# Out:
#                                     document_id  \
# 0     d4783ade-956d-4518-b37e-23cc7d82aacd-i0b0
# 1     db9d9571-c2b6-4bc7-8f2d-ab5c51a8a1d3-i0b0
# 2     6920e1cf-dc29-4a7f-8dc7-dd950ad592c4-i0b0
# 3     d47dfa6e-2cf6-42df-b8c1-de065b77d9d9-i0b0
# 4     d5816c39-1d27-4336-be8f-b8f43b9be78b-i0b0
# ...                                         ...
# 2284  95f51a07-88e9-422e-a77f-6b2ea4be7e1f-i0b0
# 2285  d1523ff5-9963-4dfe-bc74-f430cd1044fe-i0b0
# 2286  a8cf8840-8127-4927-9fa7-a2e69f7946f7-i0b0
# 2287  4633b490-86cd-411b-be2d-0c0df5e062a2-i0b0
# 2288  7436172d-5e09-4308-b267-352f3577d4c1-i0b0
#
#                                             paciente_id  paciente_idade  \
# 0     6ea30a5fde368f129ec63b5b5c850db343cc6634698f7b...               9
# 1     69a322bcf6326a295c1ea3717338d4470f6db59539a8cb...              12
# 2     0b1db0004ae457624212eb90df953bc981f26fdf0d9544...              15
# 3     a0059073268409b486ff765a0ce61048275021971a9994...               4
# ...
